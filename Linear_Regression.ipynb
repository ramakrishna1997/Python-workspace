# %%
import numpy as np
import pandas as pd

# %%
startups=pd.read_csv("C:/Users/Ramakrishna/Desktop/50_Startups.csv",encoding='cp1252',sep=',')

# %%
startups
# Out:
#             Company  R&D Spend  Administration  Marketing Spend       State  \
# 0     Urban Company  165349.20       136897.80        471784.10    New York
# 1         Classplus  162597.70       151377.59        443898.53  California
# 2             Paytm  153441.51       101145.55        407934.54     Florida
# 3              Apna  144372.41       118671.85        383199.62    New York
# 4          Razorpay  142107.34        91391.77        366168.42     Florida
# 5      Zoho Company  131876.90        99814.71        362861.36    New York
# 6            UpGrad  134615.46       147198.87        127716.82  California
# 7         Delhivery  130298.13       145530.06        323876.68     Florida
# 8               1mg  120542.52       148718.95        311613.29    New York
# 9         BigBasket  123334.88       108679.17        304981.62  California
# 10         Dearm 11  101913.08       110594.11        229160.95     Florida
# ...

# %%
df=startups.copy()

# %%
df.index.name='index'

# %%
df.index.column='index'

# %%
df
# Out:
#                Company  R&D Spend  Administration  Marketing Spend  \
# index
# 0        Urban Company  165349.20       136897.80        471784.10
# 1            Classplus  162597.70       151377.59        443898.53
# 2                Paytm  153441.51       101145.55        407934.54
# 3                 Apna  144372.41       118671.85        383199.62
# 4             Razorpay  142107.34        91391.77        366168.42
# 5         Zoho Company  131876.90        99814.71        362861.36
# 6               UpGrad  134615.46       147198.87        127716.82
# 7            Delhivery  130298.13       145530.06        323876.68
# 8                  1mg  120542.52       148718.95        311613.29
# 9            BigBasket  123334.88       108679.17        304981.62
# 10            Dearm 11  101913.08       110594.11        229160.95
# 11          GoMechanic  100671.96        91790.61        249744.55
# 12              Revolt   93863.75       127320.38        249839.44
# ...

# %%
import seaborn as sns
# %matplotlib inline

# %%
sns.lmplot(x="R&D Spend",y="Profit",data=df,hue="Company")

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["R&D Spend"],df["Profit"])

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='index'>

# %%
#df=df.describe()

# %%
df
# Out:
#                Company  R&D Spend  Administration  Marketing Spend  \
# index
# 0        Urban Company  165349.20       136897.80        471784.10
# 1            Classplus  162597.70       151377.59        443898.53
# 2                Paytm  153441.51       101145.55        407934.54
# 3                 Apna  144372.41       118671.85        383199.62
# 4             Razorpay  142107.34        91391.77        366168.42
# 5         Zoho Company  131876.90        99814.71        362861.36
# 6               UpGrad  134615.46       147198.87        127716.82
# 7            Delhivery  130298.13       145530.06        323876.68
# 8                  1mg  120542.52       148718.95        311613.29
# 9            BigBasket  123334.88       108679.17        304981.62
# 10            Dearm 11  101913.08       110594.11        229160.95
# 11          GoMechanic  100671.96        91790.61        249744.55
# 12              Revolt   93863.75       127320.38        249839.44
# ...

# %%
df.columns
# Out:
# Index(['Company', 'R&D Spend', 'Administration', 'Marketing Spend', 'State',
#        'Profit'],
#       dtype='object')

# %%
X=df[['R&D Spend', 'Administration', 'Marketing Spend']]

# %%
y=df['Profit']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=102)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lm.intercept_)
# Out:
# 50228.622182730556

# %%
print(lm.coef_)
# Out:
# [ 0.79400274 -0.03281514  0.03132227]

# %%
data=pd.DataFrame(lm.coef_,columns=["cofficent"])

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
pred=lm.predict(X_test)

# %%
sns.distplot(y_test-pred)
# Out:
# C:\Users\Ramakrishna\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %%
sns.scatterplot(y_test,pred)
# Out:
# C:\Users\Ramakrishna\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Profit'>

# %%
from sklearn import metrics

# %%
MAE=metrics.mean_absolute_error(y_test,pred)
MSE=metrics.mean_squared_error(y_test,pred)
SMSE=np.sqrt(metrics.mean_squared_error(y_test,pred))

# %%
print(f"the mean absolute error {MAE}")
print(f"the mean squared error {MSE}")
print(f"the mean sequare root error {SMSE}")
# Out:
# the mean absolute error 4111.918671099164
# the mean squared error 28344229.85616336
# the mean sequare root error 5323.929925925337

# %%
#X1,Y=np.meshgrid(X_train,y_test)
plt.plot(X_train,y_train)
plt.show()

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
x=df["R&D Spend"]
y=df["Profit"]

# %%
X=x.values.reshape((len(x),1))
Y=y.values.reshape((len(y),1))
plt.scatter(x,y)
reg_model.fit(X,Y)
plt.plot(X,reg_model.predict(X),lw=2,color='r')
plt.show()

# %%
from sklearn import linear_model
reg_model=linear_model.LinearRegression()

# %%
x1=df['Administration']
y1=df['Marketing Spend']
X1=x1.values.reshape((len(x1),1))
Y1=y1.values.reshape((len(y1),1))
plt.scatter(x1,y1)
reg_model.fit(X1,Y1)
plt.plot(X1,reg_model.predict(X1),lw=2,color='g')
plt.show()

# %%
df.State.value_counts()
# Out:
# New York      17
# California    17
# Florida       16
# Name: State, dtype: int64

# %%
sns.pairplot(data=df,hue='State')

# %%
df
# Out:
#             Company  R&D Spend  Administration  Marketing Spend       State  \
# 0     Urban Company  165349.20       136897.80        471784.10    New York
# 1         Classplus  162597.70       151377.59        443898.53  California
# 2             Paytm  153441.51       101145.55        407934.54     Florida
# 3              Apna  144372.41       118671.85        383199.62    New York
# 4          Razorpay  142107.34        91391.77        366168.42     Florida
# 5      Zoho Company  131876.90        99814.71        362861.36    New York
# 6            UpGrad  134615.46       147198.87        127716.82  California
# 7         Delhivery  130298.13       145530.06        323876.68     Florida
# 8               1mg  120542.52       148718.95        311613.29    New York
# 9         BigBasket  123334.88       108679.17        304981.62  California
# 10         Dearm 11  101913.08       110594.11        229160.95     Florida
# ...

# %%
x=df[["R&D Spend","Administration"]]
y=df["Profit"]

# %%
from sklearn import linear_model

# %%
reg_model=linear_model.LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
train_test_split
# Out:
# <function sklearn.model_selection._split.train_test_split(*arrays, test_size=None, train_size=None, random_state=None, shuffle=True, stratify=None)>

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.5, random_state=42)

# %%
reg_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg_model.score(X_test,y_test)
# Out:
# 0.9338304984784245

# %%
pred=reg_model.predict(X_test)

# %%
pred
# Out:
# array([126414.49589802,  87643.81198972, 103110.74949574,  47919.75355354,
#        127235.66389221,  59081.78564396, 110327.60512683, 101647.83204475,
#        102190.09452621, 118617.96244284, 129371.8775084 , 177689.0267344 ,
#         97571.4510098 , 149499.51261158, 175330.50941704, 162162.60212724,
#         77954.6083609 ,  49529.6493028 ,  45236.15086316, 148356.86023387,
#        158359.71159482, 116296.8002312 , 119006.19026903,  82653.33596531,
#         96433.53341454])

# %%
import numpy as np

reg_model.score(X_test,y_test)
# Out:
# 0.9338304984784245

# %%
reg_model
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

# %%
#score=r2_score(y_test,pred)
y_test.shape
# Out:
# (1,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import numpy as np

# Generate some sample data
X = np.array([[1, 2], [3, 4], [5, 6], [7, 8]])
y = np.array([3, 7, 11, 15])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Train a linear regression model
reg_model = LinearRegression()
reg_model.fit(X_train, y_train)

# Make predictions on the test set
y_pred = reg_model.predict(X_test)

# Calculate the R-squared score using the predicted and true values
score = r2_score(y_test, y_pred)

print('R-squared score:', score)
# Out:
# R-squared score: nan
# C:\Users\Ramakrishna\anaconda3\lib\site-packages\sklearn\metrics\_regression.py:796: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
